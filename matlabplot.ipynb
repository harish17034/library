# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import style

# %%
plt.title('graph')
x=[2,6,3]
y=[5,6,9]
plt.plot(x,y,'b',label='example',linewidth=3)
plt.legend()
plt.xlabel('time')
plt.ylabel('freq')
plt.grid(True,color='r')

# %%
x=[2,1,4]
plt.plot(x)

# %%
plt.bar([4,3,2],[5,6,1],label='eg 1')
plt.bar([5,3,3],[2,2,1],label='eg 2')
plt.xlabel('time')
plt.ylabel('freq')
plt.show()
